# %%
from PIL import Image
from MastodonT13 import *

# Initialize new object
mas_obj = MastodonT13()

# Query Hashtag List
hashtag_list = mas_obj.hashtag_list()
print(hashtag_list)
# Out:
# ['chatgpt', 'covid', 'eurovision', 'gaming', 'mastodon', 'news', 'photography', 'russia', 'ukraine']

# %%
# Generate Bar Chart (based on all mastodon data)
bar_chart = Image.open(mas_obj.bar_chart())
bar_chart.show()

# %%
# Generate Histogram (based on a certain hashtag e.g., covid)
histogram = Image.open(mas_obj.histogram("covid"))
histogram.show()
